# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16725, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 16725 (delta 137), reused 156 (delta 80), pack-reused 16459
# Receiving objects: 100% (16725/16725), 15.41 MiB | 21.64 MiB/s, done.
# Resolving deltas: 100% (11440/11440), done.
# /content/yolov5/yolov5/yolov5
# Setup complete. Using torch 2.3.0+cu121 (Tesla T4)

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XWjxucFvUZIKB7eeA2x6")
project = rf.workspace("sneha-w2mic").project("car_bike-tvhus")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !python train.py --img 416 --batch 4 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-07-02 10:23:41.078783: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-02 10:23:41.078833: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-02 10:23:41.080222: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# source /path ---> images
# source 0 -----> webcam
# source /path of video
# source ---> url of youtube

# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/datasets/car_bike-2/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-334-g100a423b Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/16 /content/datasets/car_bike-2/test/images/11c_jpeg.rf.2ce7206f2f0c7bb7ec37874673a1cdf3.jpg: 416x416 1 car, 7.1ms
# image 2/16 /content/datasets/car_bike-2/test/images/14c_jpeg.rf.6c32ce64b38446b494b230d26935403a.jpg: 416x416 1 car, 7.2ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/ima.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/ima.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-334-g100a423b Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/ima.jpg: 256x416 1 bike, 47.9ms
# Speed: 0.4ms pre-process, 47.9ms inference, 570.3ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --weights /content/yolov5/yolov5/yolov5s.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov5/yolov5/yolov5s.pt'], source=/content/datasets/car_bike-2/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-334-g100a423b Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/16 /content/datasets/car_bike-2/test/images/11c_jpeg.rf.2ce7206f2f0c7bb7ec37874673a1cdf3.jpg: 416x416 1 truck, 7.4ms
# ...
